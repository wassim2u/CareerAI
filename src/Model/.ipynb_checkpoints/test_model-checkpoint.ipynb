# %%
import pathlib
import google.generativeai as genai
import os

GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-1.5-flash')

chat = model.start_chat(history=[])


cookie_picture = {
    'mime_type': 'image/jpeg',
    'data': pathlib.Path("/Users/wassim/Documents/Projects/LevelUp/Resume.jpg").read_bytes()
}
introduction_prompt = "I would like some help with job application. Please find my resume attached. \
Here is the job description I want to apply to. Please give me detailed feedback, and tell me if I fit the role. Please ask me three questions you would like me to answer if you would like more information before giving a feedback.\
Please also, after the feedback, provide some courses in Google and/or Coursera if needed to upgrade my skills. Could you also provide some table structured information along with the feedback to have data visualisation for me based on the feedback, job description, and resume? For example, i want some information that can showcase my : "
extra_prompt = "Please note the number of years of experience, and the seniority of the role. Indicate whether i need more experience to be able to fit within the role. Watch out for unconsious bias."
question_prompt = "" #Additional answers to questions asked by Gemini.
job_text_file = open("../../careers/tech/example.txt")
job_text = job_text_file.read()
job_text_link = "https://www.google.com/about/careers/applications/jobs/results/142343026188919494-senior-research-scientist-google-research"
prompt = introduction_prompt +  job_text_link
response = chat.send_message(
    [prompt, cookie_picture]
)
print(response.text)      

    
    
job_text_file.close()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[2], line 25
#      23 job_text_link = "https://www.google.com/about/careers/applications/jobs/results/142343026188919494-senior-research-scientist-google-research"
#      24 prompt = introduction_prompt +  job_text_link
# ---> 25 response = chat.send_message(
#      26     [prompt, cookie_picture]
#      27 )
#      28 print(response.text)
#      32 job_text_file.close()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/generativeai/generative_models.py:578, in ChatSession.send_message(self, content, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     573 if generation_config.get("candidate_count", 1) > 1:
#     574     raise ValueError(
#     575         "Invalid configuration: The chat functionality does not support `candidate_count` greater than 1."
#     576     )
# --> 578 response = self.model.generate_content(
#     579     contents=history,
#     580     generation_config=generation_config,
#     581     safety_settings=safety_settings,
#     582     stream=stream,
#     583     tools=tools_lib,
#     584     tool_config=tool_config,
#     585     request_options=request_options,
#     586 )
#     588 self._check_response(response=response, stream=stream)
#     590 if self.enable_automatic_function_calling and tools_lib is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/generativeai/generative_models.py:317, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     314     request.contents[-1].role = _USER_ROLE
#     316 if self._client is None:
# --> 317     self._client = client.get_default_generative_client()
#     319 if request_options is None:
#     320     request_options = {}
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/generativeai/client.py:339, in get_default_generative_client()
#     338 def get_default_generative_client() -> glm.GenerativeServiceClient:
# --> 339     return _client_manager.get_default_client("generative")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/generativeai/client.py:259, in _ClientManager.get_default_client(self, name)
#     257 client = self.clients.get(name)
#     258 if client is None:
# --> 259     client = self.make_client(name)
#     260     self.clients[name] = client
#     261 return client
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/generativeai/client.py:217, in _ClientManager.make_client(self, name)
#     210 except ga_exceptions.DefaultCredentialsError as e:
#     211     e.args = (
#     212         "\n  No API_KEY or ADC found. Please either:\n"
#     213         "    - Set the `GOOGLE_API_KEY` environment variable.\n"
#     214         "    - Manually pass the key with `genai.configure(api_key=my_api_key)`.\n"
#     215         "    - Or set up Application Default Credentials, see https://ai.google.dev/gemini-api/docs/oauth for more information.",
#     216     )
# --> 217     raise e
#     219 if not self.default_metadata:
#     220     return client
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/generativeai/client.py:209, in _ClientManager.make_client(self, name)
#     207 try:
#     208     with patch_colab_gce_credentials():
# --> 209         client = cls(**self.client_config)
#     210 except ga_exceptions.DefaultCredentialsError as e:
#     211     e.args = (
#     212         "\n  No API_KEY or ADC found. Please either:\n"
#     213         "    - Set the `GOOGLE_API_KEY` environment variable.\n"
#     214         "    - Manually pass the key with `genai.configure(api_key=my_api_key)`.\n"
#     215         "    - Or set up Application Default Credentials, see https://ai.google.dev/gemini-api/docs/oauth for more information.",
#     216     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:687, in GenerativeServiceClient.__init__(self, credentials, transport, client_options, client_info)
#     678 transport_init: Union[
#     679     Type[GenerativeServiceTransport],
#     680     Callable[..., GenerativeServiceTransport],
#    (...)
#     684     else cast(Callable[..., GenerativeServiceTransport], transport)
#     685 )
#     686 # initialize with the provided callable or the passed in class
# --> 687 self._transport = transport_init(
#     688     credentials=credentials,
#     689     credentials_file=self._client_options.credentials_file,
#     690     host=self._api_endpoint,
#     691     scopes=self._client_options.scopes,
#     692     client_cert_source_for_mtls=self._client_cert_source,
#     693     quota_project_id=self._client_options.quota_project_id,
#     694     client_info=client_info,
#     695     always_use_jwt_access=True,
#     696     api_audience=self._client_options.api_audience,
#     697 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/grpc.py:153, in GenerativeServiceGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     148             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     149                 certificate_chain=cert, private_key=key
#     150             )
#     152 # The base transport sets the host, credentials and scopes
# --> 153 super().__init__(
#     154     host=host,
#     155     credentials=credentials,
#     156     credentials_file=credentials_file,
#     157     scopes=scopes,
#     158     quota_project_id=quota_project_id,
#     159     client_info=client_info,
#     160     always_use_jwt_access=always_use_jwt_access,
#     161     api_audience=api_audience,
#     162 )
#     164 if not self._grpc_channel:
#     165     # initialize with the provided callable or the default channel
#     166     channel_init = channel or type(self).create_channel
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/base.py:98, in GenerativeServiceTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#      94     credentials, _ = google.auth.load_credentials_from_file(
#      95         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#      96     )
#      97 elif credentials is None:
# ---> 98     credentials, _ = google.auth.default(
#      99         **scopes_kwargs, quota_project_id=quota_project_id
#     100     )
#     101     # Don't apply audience if the credentials file passed from user.
#     102     if hasattr(credentials, "with_gdch_audience"):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/CareerAI/lib/python3.10/site-packages/google/auth/_default.py:691, in default(scopes, request, quota_project_id, default_scopes)
#     683             _LOGGER.warning(
#     684                 "No project ID could be determined. Consider running "
#     685                 "`gcloud config set project` or setting the %s "
#     686                 "environment variable",
#     687                 environment_vars.PROJECT,
#     688             )
#     689         return credentials, effective_project_id
# --> 691 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError:
#   No API_KEY or ADC found. Please either:
#     - Set the `GOOGLE_API_KEY` environment variable.
#     - Manually pass the key with `genai.configure(api_key=my_api_key)`.
#     - Or set up Application Default Credentials, see https://ai.google.dev/gemini-api/docs/oauth for more information.
